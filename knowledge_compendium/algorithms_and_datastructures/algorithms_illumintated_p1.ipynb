// %% [markdown]
// # Algorithms Illuminated Part 1
//
// This is part 1 of my notes for the [algorithms illuminated](https://youtube.com/playlist?list=PLEGCF-WLh2RLHqXx6-GZr_w7LgqKDXxN_&si=F_Br-YQVAlhE8GxM) youtube series.
//
//
// ## Integer Multiplication
// **Input**: Two n-digit integers
//
// **Output**: The product of the 2 integers
//
//
// There are 2 types of algorithms that we want to explore here:
// 1. The third grade mulitplication algorithm.
// 2. Karatsuba multiplication algorithm
//
//
// ### Third Grade Multiplication algorithm
//
// Taking as an example the inputs a: 1234 and b: 5678, in third grade the computation is as follows:
//
// ![third_grade_multiplication](../images/third_grade_multiplication.png)
//
// Let's now try to implement and analyze this algorithm.

// %%
// Get the number as a list of digits
fn to_digits_list(n: i8) -> i8[] {
    let mut digits_list: i8[];
    while (n > 0)
    {
        
    }
}


// Let's first start with the 3-d grade approach to multiplication
fn third_grade_muliplication(a: i8, b: i8) -> i8 {
    let mut a_copy = a;
    let mut b_copy = b;
    while (a_copy > 0) {
        let digit = a_copy % 10;
        a_copy /= 10;
    }
    return 0;
}
// Out:
// Error: expected one of `!`, `(`, `+`, `::`, `<`, `where`, or `{`, found `#`
//    ╭─[ command_5:1:1 ]
//    │
//  2 │ fn to_digits_list(n: i8) -> i8[] {
//    │                               │
//    │                               ╰─ expected one of 7 possible tokens
// ───╯
